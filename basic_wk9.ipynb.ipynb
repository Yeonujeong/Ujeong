# %%
import tensorflow as tf
import pandas as pd
import numpy as np
import missingno as msno
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train_file = 'C:/Users/yeonujeong/Desktop/titanic/train.csv'
test_file = 'C:/Users/yeonujeong/Desktop/titanic/test.csv' #파일 경로에 한글이 없어야 하고, \ 기호는 / 기호로 바꿔야 오류가 안 뜬다
train = pd.read_csv(train_file)
test = pd.read_csv(test_file)
print(train.columns)
train.head()
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# 고유값 개수 확인
train.nunique()
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             88
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          147
# Embarked         3
# dtype: int64

# %%
# 결측치를 포함한 고유값 개수 확인
train.nunique(dropna = False)
# Out:
# PassengerId    891
# Survived         2
# Pclass           3
# Name           891
# Sex              2
# Age             89
# SibSp            7
# Parch            7
# Ticket         681
# Fare           248
# Cabin          148
# Embarked         4
# dtype: int64

# %%
# 모든 데이터가 다른 고유값을 가지는 PassengerId와 Name을 제외한
# 고유값 개수가 10이하인 데이터들과 Survived의 상관여부 분석

# Pclass에 따른 생존여부
# . (상관성 O)
# 높은 클래스 탑승객들의 생존율이 더 높음을. (상관성 O)
sns.countplot(data=train, x='Pclass', hue='Survived')
# Out:
# <AxesSubplot:xlabel='Pclass', ylabel='count'>

# %%
# Sex에 따른 생존여부 도표를 통해, 남성보다 여성의 생존율이 더 높음을 알 수 있다. (상관성 O)
sns.countplot(data=train, x='Sex', hue='Survived')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %%
# SibSp에 따른 생존여부 도표를 통해, 형제가 많지 않은 승객들이 많았다는 것은 알 수 있으나 생존률과의 상관관계는 확신할 수 없다.
sns.countplot(data=train, x='SibSp', hue='Survived')
# Out:
# <AxesSubplot:xlabel='SibSp', ylabel='count'>

# %%
# Parch에 따른 생존여부 역시 SibSp와 같은 맥락
sns.countplot(data=train, x='Parch', hue='Survived')
# Out:
# <AxesSubplot:xlabel='Parch', ylabel='count'>

# %%
# Embarked에 따른 생존여부는, 많은 탑승객이 Southampton(S)에서 승선하였다는 것을 알 수 있으나 생존여부와 관련이 있는지는 확신할 수 없다.
sns.countplot(data=train, x='Embarked', hue='Survived')
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
# train 데이터와 test 데이터의 전처리를 동시에 하기 위해 두 데이터를 합쳐준다.
# test에는 Survived column이 없기 때문에 임의로 만들어 넣어주어야 한다.
# loc는 어디에 넣던지 상관은 없지만 데이터를 더 보기 쉽게하기 위해
# train과 동일한 위치에 넣어준다.
test.insert(loc=1, column='Survived', value=0)
test.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         0       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
# train 데이터의 바로 밑에 test 데이터를 넣어준 뒤 (axis=0일때는 행을 concat 1일때는 열을 concat)
# tail로 잘 들어갔는지 확인해준다.
data = pd.concat([train, test], axis=0)
data.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         0       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
# 결측치 확인
data.isna().sum()
# Out:
# PassengerId       0
# Survived          0
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
# 결측치 시각화
import missingno as msno
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %%
# 결측치가 반 이상인 column을 삭제
# column 'Cabin'이 삭제됐음을 확인할 수 있다.
data = data.dropna(thresh=int(len(train)*0.5), axis=1)
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %%
# Age의 결측치를 처리하기 위해 Age의 값의 분포를 알아본 결과
# 상당히 대칭적인 분포를 가지고 있기 때문에 평균값으로 결측치를 처리하려 한다.
sns.countplot(data=data, x='Age')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='count'>

# %%
# Age의 평균값인 29.881137667304014로 결측치가 처리되었다.
age_mean = data['Age'].mean()
print(age_mean)
data['Age'] = data['Age'].fillna(age_mean)
msno.matrix(data)
# Out:
# 29.881137667304014
# <AxesSubplot:>

# %%
# Fare의 결측치를 처리하기 위해 Fare의 값의 분포를 알아본 결과
# 평균을 사용하기엔 이상치의 값이 꽤 있는걸로 보아 중앙값으로 결측치를 처리하려 한다.
sns.countplot(data=data, x='Fare')
# Out:
# <AxesSubplot:xlabel='Fare', ylabel='count'>

# %%
# Fare의 중앙값인 14.4542로 결측치가 처리되었다.
fare_median = data['Fare'].median()
print(fare_median)
data['Fare'] = data['Fare'].fillna(fare_median)
msno.matrix(data)
# Out:
# 14.4542
# <AxesSubplot:>

# %%
# Embarked의 결측치를 처리하기 위해 Embarked의 값의 분포를 알아본 결과
# 값의 분포가 S에 몰려있기 때문에 최빈값으로 결측치를 처리하려 한다.
sns.countplot(data=data, x='Embarked')
# Out:
# <AxesSubplot:xlabel='Embarked', ylabel='count'>

# %%
# Embarked의 결측치가 최빈값인 'S'로 처리되었다.
data['Embarked'] = data['Embarked'].fillna('S')
msno.matrix(data)
# Out:
# <AxesSubplot:>

# %%
# 범주형 데이터를 처리하기 전에, 
# PassengerId와 Name, Ticket은 생존여부와 관계가 없으므로 제외해준다.
# 대신 나중에 passenger_id는 output에 추가해주기 위해 미리 값을 저장해준다.
passenger_id = data[['PassengerId']].copy()
data = data.drop(['PassengerId', 'Name', 'Ticket'], axis=1)
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
# 원핫인코딩
data = pd.get_dummies(data)
data.head()
# Out:
#    Survived  Pclass   Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0         0       3  22.0      1      0   7.2500           0         1
# 1         1       1  38.0      1      0  71.2833           1         0
# 2         1       3  26.0      0      0   7.9250           1         0
# 3         1       1  35.0      1      0  53.1000           1         0
# 4         0       3  35.0      0      0   8.0500           0         1
#
#    Embarked_C  Embarked_Q  Embarked_S
# 0           0           0           1
# 1           1           0           0
# 2           0           0           1
# 3           0           0           1
# 4           0           0           1

# %%
# 데이터 전처리를 끝낸 뒤 train과 test를 다시 나눠준다.
train, test = data[:len(train)], data[len(train):]
print(train.shape)
print(test.shape)
test.tail()
# Out:
# (891, 11)
# (418, 11)
#      Survived  Pclass        Age  SibSp  Parch      Fare  Sex_female  \
# 413         0       3  29.881138      0      0    8.0500           0
# 414         0       1  39.000000      0      0  108.9000           1
# 415         0       3  38.500000      0      0    7.2500           0
# 416         0       3  29.881138      0      0    8.0500           0
# 417         0       3  29.881138      1      1   22.3583           0
#
#      Sex_male  Embarked_C  Embarked_Q  Embarked_S
# 413         1           0           0           1
# 414         0           1           0           0
# 415         1           0           0           1
# 416         1           0           0           1
# 417         1           1           0           0

# %%
# 독립, 종속변수 분리
print(train.columns)
trainX = train[[ x for x in train.columns if 'Survived' not in x ]]
trainY = train[['Survived']]
print(trainX.shape, trainY.shape)
# Out:
# Index(['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare', 'Sex_female',
#        'Sex_male', 'Embarked_C', 'Embarked_Q', 'Embarked_S'],
#       dtype='object')
# (891, 10) (891, 1)

# %%
# 모델 구조 만들기
#진행하는 이진 분류 문제를 위해 입력 레이어는 X, 출력 레이어는 Y
#그 사이에 은닉 레이어 H를 가진 모델을 구성했다. 
#이때, 손실 함수를 binary cross entropy 함수로 하며, 평가 지표는 accuracy를 사용한다. 
#Dense 층은 20개에서 5개 단위로 줄여 결과적으로 1개까지 줄여나가는 모델을 구현했다.(추상적인 모델까지 학습이 가능하도록 함)

X = tf.keras.layers.Input(shape=[10])
H = tf.keras.layers.Dense(20, activation='swish')(X)
H = tf.keras.layers.Dense(15, activation='swish')(H)
H = tf.keras.layers.Dense(10, activation='swish')(H)
H = tf.keras.layers.Dense(5, activation='swish')(H)
H = tf.keras.layers.Dense(1, activation='swish')(H)
Y = tf.keras.layers.Dense(1, activation='sigmoid')(H)
model = tf.keras.models.Model(X, Y)
model.compile(loss='binary_crossentropy',
              metrics='accuracy')

# %%
model.fit(trainX, trainY, epochs=100, batch_size=150, verbose=0)
model.fit(trainX, trainY, epochs=10, batch_size=150)
# Out:
# Epoch 1/10
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5722 - accuracy: 0.6543
# Epoch 2/10
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5704 - accuracy: 0.6566
# Epoch 3/10
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5709 - accuracy: 0.6532
# Epoch 4/10
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5714 - accuracy: 0.6521
# Epoch 5/10
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5745 - accuracy: 0.6532
# Epoch 6/10
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5692 - accuracy: 0.6554
# Epoch 7/10
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5703 - accuracy: 0.6532
# Epoch 8/10
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5688 - accuracy: 0.6554
# Epoch 9/10
# 6/6 [==============================] - 0s 3ms/step - loss: 0.5684 - accuracy: 0.6543
# Epoch 10/10
# 6/6 [==============================] - 0s 2ms/step - loss: 0.5728 - accuracy: 0.6543

# %%
model.fit(trainX, trainY, epochs=1000, batch_size=200, verbose=0) #성능 향상을 위해 epochs와 batch_size를 늘림
model.fit(trainX, trainY, epochs=10, batch_size=200)
# Out:
# Epoch 1/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4398 - accuracy: 0.8249
# Epoch 2/10
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4354 - accuracy: 0.8328
# Epoch 3/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4398 - accuracy: 0.8272
# Epoch 4/10
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4368 - accuracy: 0.8339
# Epoch 5/10
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4379 - accuracy: 0.8361
# Epoch 6/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4388 - accuracy: 0.8305
# Epoch 7/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4363 - accuracy: 0.8294
# Epoch 8/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4362 - accuracy: 0.8328
# Epoch 9/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4380 - accuracy: 0.8283
# Epoch 10/10
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4339 - accuracy: 0.8373

# %%
model.fit(trainX, trainY, epochs=10000, batch_size=300, verbose=0)#성능 향상을 위해 epochs와 batch_size를 늘림.
model.fit(trainX, trainY, epochs=10, batch_size=300)
# Out:
# Epoch 1/10
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1828 - accuracy: 0.9304
# Epoch 2/10
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1783 - accuracy: 0.9349
# Epoch 3/10
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1832 - accuracy: 0.9371
# Epoch 4/10
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1863 - accuracy: 0.9282
# Epoch 5/10
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1844 - accuracy: 0.9360
# Epoch 6/10
# 3/3 [==============================] - 0s 3ms/step - loss: 0.2006 - accuracy: 0.9248
# Epoch 7/10
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1903 - accuracy: 0.9282
# Epoch 8/10
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1883 - accuracy: 0.9304
# Epoch 9/10
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1770 - accuracy: 0.9349
# Epoch 10/10
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1830 - accuracy: 0.9327

# %%
model.fit(trainX, trainY, epochs=10000, batch_size=300, verbose=0)#성능 향상을 위해 epochs와 batch_size를 늘림, 과적합을 방지하고자 여기서 멈춤
model.fit(trainX, trainY, epochs=100, batch_size=300)
# Out:
# Epoch 1/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1634 - accuracy: 0.9360
# Epoch 2/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1447 - accuracy: 0.9461
# Epoch 3/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1590 - accuracy: 0.9439
# Epoch 4/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1710 - accuracy: 0.9293
# Epoch 5/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1652 - accuracy: 0.9383
# Epoch 6/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1585 - accuracy: 0.9383
# Epoch 7/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1625 - accuracy: 0.9270
# Epoch 8/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1598 - accuracy: 0.9327
# Epoch 9/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1840 - accuracy: 0.9270
# Epoch 10/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1401 - accuracy: 0.9439
# Epoch 11/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1424 - accuracy: 0.9416
# Epoch 12/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1573 - accuracy: 0.9349
# Epoch 13/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1455 - accuracy: 0.9428
# Epoch 14/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1626 - accuracy: 0.9327
# Epoch 15/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1628 - accuracy: 0.9360
# Epoch 16/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1759 - accuracy: 0.9327
# Epoch 17/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1543 - accuracy: 0.9349
# Epoch 18/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1544 - accuracy: 0.9371
# Epoch 19/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1546 - accuracy: 0.9450
# Epoch 20/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1534 - accuracy: 0.9360
# Epoch 21/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1537 - accuracy: 0.9383
# Epoch 22/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1506 - accuracy: 0.9416
# Epoch 23/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1542 - accuracy: 0.9394
# Epoch 24/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1553 - accuracy: 0.9439
# Epoch 25/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1549 - accuracy: 0.9416
# Epoch 26/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1494 - accuracy: 0.9450
# Epoch 27/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1621 - accuracy: 0.9360
# Epoch 28/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1423 - accuracy: 0.9473
# Epoch 29/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1454 - accuracy: 0.9439
# Epoch 30/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1891 - accuracy: 0.9259
# Epoch 31/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1502 - accuracy: 0.9439
# Epoch 32/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1773 - accuracy: 0.9383
# Epoch 33/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1942 - accuracy: 0.9327
# Epoch 34/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1507 - accuracy: 0.9394
# Epoch 35/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1495 - accuracy: 0.9405
# Epoch 36/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1457 - accuracy: 0.9450
# Epoch 37/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1575 - accuracy: 0.9349
# Epoch 38/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1495 - accuracy: 0.9405
# Epoch 39/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1445 - accuracy: 0.9450
# Epoch 40/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1587 - accuracy: 0.9394
# Epoch 41/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1664 - accuracy: 0.9315
# Epoch 42/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1504 - accuracy: 0.9428
# Epoch 43/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1467 - accuracy: 0.9416
# Epoch 44/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2089 - accuracy: 0.9226
# Epoch 45/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1618 - accuracy: 0.9405
# Epoch 46/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1570 - accuracy: 0.9394
# Epoch 47/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1473 - accuracy: 0.9450
# Epoch 48/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1562 - accuracy: 0.9428
# Epoch 49/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1626 - accuracy: 0.9405
# Epoch 50/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1516 - accuracy: 0.9394
# Epoch 51/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1525 - accuracy: 0.9439
# Epoch 52/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1427 - accuracy: 0.9416
# Epoch 53/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1637 - accuracy: 0.9383
# Epoch 54/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1510 - accuracy: 0.9450
# Epoch 55/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1577 - accuracy: 0.9416
# Epoch 56/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1468 - accuracy: 0.9461
# Epoch 57/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1454 - accuracy: 0.9428
# Epoch 58/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1769 - accuracy: 0.9349
# Epoch 59/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1681 - accuracy: 0.9383
# Epoch 60/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1565 - accuracy: 0.9416
# Epoch 61/100
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1648 - accuracy: 0.9371
# Epoch 62/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1670 - accuracy: 0.9327
# Epoch 63/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1511 - accuracy: 0.9450
# Epoch 64/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1444 - accuracy: 0.9450
# Epoch 65/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1401 - accuracy: 0.9461
# Epoch 66/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1475 - accuracy: 0.9428
# Epoch 67/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1554 - accuracy: 0.9428
# Epoch 68/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1510 - accuracy: 0.9405
# Epoch 69/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1818 - accuracy: 0.9304
# Epoch 70/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1951 - accuracy: 0.9203
# Epoch 71/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1557 - accuracy: 0.9383
# Epoch 72/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1460 - accuracy: 0.9428
# Epoch 73/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1417 - accuracy: 0.9473
# Epoch 74/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1392 - accuracy: 0.9473
# Epoch 75/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1685 - accuracy: 0.9360
# Epoch 76/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1466 - accuracy: 0.9405
# Epoch 77/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1409 - accuracy: 0.9473
# Epoch 78/100
# 3/3 [==============================] - 0s 4ms/step - loss: 0.1473 - accuracy: 0.9394
# Epoch 79/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1475 - accuracy: 0.9428
# Epoch 80/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1875 - accuracy: 0.9338
# Epoch 81/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1989 - accuracy: 0.9226
# Epoch 82/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1987 - accuracy: 0.9428
# Epoch 83/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1580 - accuracy: 0.9383
# Epoch 84/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1546 - accuracy: 0.9405
# Epoch 85/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1475 - accuracy: 0.9439
# Epoch 86/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1602 - accuracy: 0.9383
# Epoch 87/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1462 - accuracy: 0.9439
# Epoch 88/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1493 - accuracy: 0.9439
# Epoch 89/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2156 - accuracy: 0.9226
# Epoch 90/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2134 - accuracy: 0.9383
# Epoch 91/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1710 - accuracy: 0.9327
# Epoch 92/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1511 - accuracy: 0.9439
# Epoch 93/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1520 - accuracy: 0.9383
# Epoch 94/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1517 - accuracy: 0.9416
# Epoch 95/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1423 - accuracy: 0.9416
# Epoch 96/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1504 - accuracy: 0.9428
# Epoch 97/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1516 - accuracy: 0.9383
# Epoch 98/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1489 - accuracy: 0.9439
# Epoch 99/100
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1826 - accuracy: 0.9282
# Epoch 100/100
# 3/3 [==============================] - 0s 3ms/step - loss: 0.1648 - accuracy: 0.9371

# %%
# 전에 저장해준 PassengerId값을 test범위만큼 잘라내어 result에 넣어준다.
result = passenger_id[len(train):]
result.head()
# Out:
#    PassengerId
# 0          892
# 1          893
# 2          894
# 3          895
# 4          896

# %%
# 예측해준 값을 0 또는 1로 round 해준 뒤 result에 결과값을 넣어준다
testX = test[[ x for x in test.columns if 'Survived' not in x ]]
testY = np.round(model.predict(testX))
testY = pd.DataFrame(testY, columns = ['Survived'], dtype = int)
result = pd.concat([result, testY], axis=1)
result = result.set_index('PassengerId')
result.head()
# Out:
# 14/14 [==============================] - 0s 847us/step
#              Survived
# PassengerId
# 892                 0
# 893                 0
# 894                 0
# 895                 1
# 896                 0
